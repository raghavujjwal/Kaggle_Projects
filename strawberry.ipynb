# %% [markdown]
# <a href="https://www.kaggle.com/code/ujjwalraghav69/strawberry?scriptVersionId=216255752" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
test = pd.read_csv('/kaggle/input/regression-dataset/test.csv')
train = pd.read_csv('/kaggle/input/regression-dataset/train.csv')
train.head(5)
# Out:
#    id   Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0   0  728.0       25.0      0.50     0.38     0.50   0.63              86.0
# 1   1  657.0       25.0      0.50     0.38     0.38   0.63              69.7
# 2   2  441.0       12.5      0.25     0.38     0.50   0.75              77.4
# 3   3  547.0       25.0      0.50     0.25     0.50   0.75              77.4
# 4   4  692.0       25.0      0.50     0.38     0.38   0.63              86.0
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              42.1                  58.2              50.2              24.3
# 2              46.8                  64.7              55.8              27.0
# 3              46.8                  64.7              55.8              27.0
# 4              52.0                  71.9              62.0              30.0
#
#    AverageOfLowerTRange  RainingDays  AverageRainingDays  fruitset  fruitmass  \
# 0                  50.8          1.0                0.10  0.551234   0.471665
# 1                  41.2         16.0                0.26  0.411591   0.398256
# 2                  45.8         24.0                0.39  0.574708   0.480106
# 3                  45.8         16.0                0.26  0.512308   0.453131
# 4                  50.8         24.0                0.39  0.464369   0.433408
#
#        seeds       yield
# 0  37.214021  6520.89760
# 1  31.875182  4218.32799
# 2  39.230391  7284.81478
# 3  36.362300  6491.22353
# 4  35.118076  6190.66597

# %%
train.shape
# Out:
# (15000, 19)

# %%
train.info
# Out:
# <bound method DataFrame.info of           id   Row#  clonesize  honeybee  bumbles  andrena  osmia  \
# 0          0  728.0       25.0      0.50     0.38     0.50   0.63
# 1          1  657.0       25.0      0.50     0.38     0.38   0.63
# 2          2  441.0       12.5      0.25     0.38     0.50   0.75
# 3          3  547.0       25.0      0.50     0.25     0.50   0.75
# 4          4  692.0       25.0      0.50     0.38     0.38   0.63
# ...      ...    ...        ...       ...      ...      ...    ...
# 14995  14995  511.0       25.0      0.50     0.25     0.50   0.75
# 14996  14996  662.0       25.0      0.50     0.25     0.38   0.50
# 14997  14997    3.0       37.5      0.75     0.25     0.25   0.25
# 14998  14998  238.0       12.5      0.25     0.25     0.50   0.50
# 14999  14999  704.0       25.0      0.50     0.25     0.50   0.50
#
#        MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# 0                  86.0              52.0                  71.9
# 1                  69.7              42.1                  58.2
# 2                  77.4              46.8                  64.7
# 3                  77.4              46.8                  64.7
# 4                  86.0              52.0                  71.9
# ...                 ...               ...                   ...
# 14995              77.4              46.8                  64.7
# 14996              86.0              52.0                  71.9
# 14997              94.6              57.2                  79.0
# 14998              69.7              42.1                  58.2
# 14999              69.7              42.1                  58.2
#
#        MaxOfLowerTRange  MinOfLowerTRange  AverageOfLowerTRange  RainingDays  \
# 0                  62.0              30.0                  50.8          1.0
# 1                  50.2              24.3                  41.2         16.0
# 2                  55.8              27.0                  45.8         24.0
# 3                  55.8              27.0                  45.8         16.0
# 4                  62.0              30.0                  50.8         24.0
# ...                 ...               ...                   ...          ...
# 14995              55.8              27.0                  45.8          1.0
# 14996              62.0              30.0                  50.8         24.0
# 14997              68.2              33.0                  55.9         34.0
# 14998              50.2              24.3                  41.2         16.0
# 14999              50.2              24.3                  41.2          1.0
#
#        AverageRainingDays  fruitset  fruitmass      seeds       yield
# 0                    0.10  0.551234   0.471665  37.214021  6520.89760
# 1                    0.26  0.411591   0.398256  31.875182  4218.32799
# 2                    0.39  0.574708   0.480106  39.230391  7284.81478
# 3                    0.26  0.512308   0.453131  36.362300  6491.22353
# 4                    0.39  0.464369   0.433408  35.118076  6190.66597
# ...                   ...       ...        ...        ...         ...
# 14995                0.10  0.566319   0.481174  40.037644  6979.32479
# 14996                0.39  0.340063   0.388819  28.417931  3436.49354
# 14997                0.56  0.383787   0.392787  29.467434  3828.16556
# 14998                0.26  0.511413   0.438026  36.249695  6735.24371
# 14999                0.10  0.506346   0.430114  36.976361  6306.55062
#
# [15000 rows x 19 columns]>

# %%
train.nunique()
# Out:
# id                      15000
# Row#                      775
# clonesize                   5
# honeybee                    7
# bumbles                     8
# andrena                    13
# osmia                      13
# MaxOfUpperTRange            5
# MinOfUpperTRange            5
# AverageOfUpperTRange        5
# MaxOfLowerTRange            5
# MinOfLowerTRange            6
# AverageOfLowerTRange        9
# RainingDays                 5
# AverageRainingDays          8
# fruitset                 1112
# fruitmass                1064
# seeds                    1209
# yield                     777
# dtype: int64

# %%
train.isnull().sum().sort_values(ascending=False)
# Out:
# id                      0
# MaxOfLowerTRange        0
# seeds                   0
# fruitmass               0
# fruitset                0
# AverageRainingDays      0
# RainingDays             0
# AverageOfLowerTRange    0
# MinOfLowerTRange        0
# AverageOfUpperTRange    0
# Row#                    0
# MinOfUpperTRange        0
# MaxOfUpperTRange        0
# osmia                   0
# andrena                 0
# bumbles                 0
# honeybee                0
# clonesize               0
# yield                   0
# dtype: int64

# %%
print(train.columns)
# Out:
# Index(['id', 'Row#', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'MaxOfUpperTRange', 'MinOfUpperTRange', 'AverageOfUpperTRange',
#        'MaxOfLowerTRange', 'MinOfLowerTRange', 'AverageOfLowerTRange',
#        'RainingDays', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds',
#        'yield'],
#       dtype='object')

# %%
train = pd.read_csv('/kaggle/input/regression-dataset/train.csv')

# %%
train.drop('MaxOfUpperTRange', inplace=True, axis=1, errors='ignore')
train.drop('MinOfUpperTRange', inplace=True, axis=1, errors='ignore')
train.drop('MaxOfLowerTRange', inplace=True, axis=1, errors='ignore')
train.drop('MinOfLowerTRange', inplace=True, axis=1, errors='ignore')
train.drop('RainingDays', inplace=True, axis=1, errors='ignore')
train.drop('fruitmass', inplace=True, axis=1, errors='ignore')
train.head(5)
# Out:
#    id   Row#  clonesize  honeybee  bumbles  andrena  osmia  \
# 0   0  728.0       25.0      0.50     0.38     0.50   0.63
# 1   1  657.0       25.0      0.50     0.38     0.38   0.63
# 2   2  441.0       12.5      0.25     0.38     0.50   0.75
# 3   3  547.0       25.0      0.50     0.25     0.50   0.75
# 4   4  692.0       25.0      0.50     0.38     0.38   0.63
#
#    AverageOfUpperTRange  AverageOfLowerTRange  AverageRainingDays  fruitset  \
# 0                  71.9                  50.8                0.10  0.551234
# 1                  58.2                  41.2                0.26  0.411591
# 2                  64.7                  45.8                0.39  0.574708
# 3                  64.7                  45.8                0.26  0.512308
# 4                  71.9                  50.8                0.39  0.464369
#
#        seeds       yield
# 0  37.214021  6520.89760
# 1  31.875182  4218.32799
# 2  39.230391  7284.81478
# 3  36.362300  6491.22353
# 4  35.118076  6190.66597

# %%
#start training and fitting the model from here

# %%
#to be used only after training the model on the training set.
def clean(test):
    test.drop('MaxOfUpperTRange', inplace=True, axis=1, errors='ignore')
    test.drop('MinOfUpperTRange', inplace=True, axis=1, errors='ignore')
    test.drop('MaxOfLowerTRange', inplace=True, axis=1, errors='ignore')
    test.drop('MinOfLowerTRange', inplace=True, axis=1, errors='ignore')
    test.drop('RainingDays', inplace=True, axis=1, errors='ignore')
    test.drop('fruitmass', inplace=True, axis=1, errors='ignore')
